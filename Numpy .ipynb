# %%
import numpy as np

# %%
round(366.87)
# Out:
# 367

# %%
round(366.87,1)
# Out:
# 366.9

# %%
a=np.floor(366.9367)
b=np.ceil(366.367)

# %%
a
# Out:
# np.float64(366.0)

# %%
b
# Out:
# np.float64(367.0)

# %%
a=int(np.floor(366.9367))
a
# Out:
# 366

# %%
b=int(np.ceil(366.367))
b
# Out:
# 367

# %%
np.power(3,2)
# Out:
# 8

# %%
int(np.power(2,3))
# Out:
# 8

# %% [markdown]
# # Array المصفوفات

# %% [markdown]
# *رقم الاعمدة*                 *رقم الصفوف*

# %%
x = [1,2,5,7,9,3,9,4]
y=np.array(x)
y
# Out:
# array([1, 2, 5, 7, 9, 3, 9, 4])

# %%
z=np.datetime64('2023-07-12')

# %%
w=np.datetime64('2023-06-12')

# %%
z+np.arange(10)
# Out:
# array(['2023-07-12', '2023-07-13', '2023-07-14', '2023-07-15',
#        '2023-07-16', '2023-07-17', '2023-07-18', '2023-07-19',
#        '2023-07-20', '2023-07-21'], dtype='datetime64[D]')

# %%
z-w
# Out:
# np.timedelta64(30,'D')

# %% [markdown]
# # عند الاحتياج لداتا وهمية

# %%
np.random.rand(3,10)
# Out:
# array([[0.3868101 , 0.26123324, 0.25490852, 0.94177974, 0.16006953,
#         0.76629968, 0.12624496, 0.53672961, 0.69382721, 0.99794184],
#        [0.17232035, 0.84402286, 0.42452561, 0.71754531, 0.52813566,
#         0.07947582, 0.15698919, 0.76694988, 0.42039697, 0.10216097],
#        [0.51044449, 0.29345707, 0.26044339, 0.9534991 , 0.60669705,
#         0.97740447, 0.97206563, 0.26113073, 0.38515252, 0.17674904]])
